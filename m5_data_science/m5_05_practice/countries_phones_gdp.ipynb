# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_computers = pd.read_csv("../Data/Trziste racunala i pametnih telefona/personal_computers_total.csv")
df_computers
# Out:
#           country  1990  1991  1992  1993  1994  1995   1996  1997  1998
# 0           Aruba   NaN   NaN   NaN   NaN   NaN   NaN    NaN   NaN   NaN  \
# 1     Afghanistan   NaN   NaN   NaN   NaN   NaN   NaN    NaN   NaN   NaN
# 2          Angola   NaN   NaN   NaN   NaN   NaN   NaN    NaN  8000   10k
# 3        Anguilla   NaN   NaN   NaN   NaN   NaN   NaN    NaN   NaN   NaN
# 4         Albania   NaN   NaN   NaN   NaN   NaN   NaN   5000   10k   15k
# ..            ...   ...   ...   ...   ...   ...   ...    ...   ...   ...
# 191         Samoa   NaN   NaN   NaN   NaN   NaN   100    300   500   800
# 192         Yemen   NaN   NaN   NaN   NaN   NaN   NaN    15k   20k   25k
# 193  South Africa  250k  333k  440k  560k  875k  1.1M  1.43M  1.8M  2.3M
# 194        Zambia   NaN   NaN   NaN   NaN   NaN   NaN    NaN   NaN   60k
# 195      Zimbabwe  2000  5000   13k   18k   22k   33k    80k  110k  130k
#
#      1999  2000  2001  2002   2003   2004   2005  2006
# ...

# %%
df_computers = df_computers.set_index("country").transpose()
df_computers
# Out:
# country Aruba Afghanistan Angola Anguilla Albania United Arab Emirates
# 1990      NaN         NaN    NaN      NaN     NaN                  NaN  \
# 1991      NaN         NaN    NaN      NaN     NaN                  NaN
# 1992      NaN         NaN    NaN      NaN     NaN                  60k
# 1993      NaN         NaN    NaN      NaN     NaN                77.8k
# 1994      NaN         NaN    NaN      NaN     NaN                  96k
# 1995      NaN         NaN    NaN      NaN     NaN                 115k
# 1996      NaN         NaN    NaN      NaN    5000                 160k
# 1997      NaN         NaN   8000      NaN     10k                 200k
# 1998      NaN         NaN    10k      NaN     15k                 250k
# 1999      NaN         NaN    12k      NaN     20k                 300k
# 2000      NaN         NaN    15k      NaN     25k                 400k
# 2001      NaN         NaN    17k      NaN     30k                 420k
# ...

# %%
df_computers.index = pd.to_datetime(df_computers.index)
df_computers
# Out:
# country    Aruba Afghanistan Angola Anguilla Albania United Arab Emirates
# 1990-01-01   NaN         NaN    NaN      NaN     NaN                  NaN  \
# 1991-01-01   NaN         NaN    NaN      NaN     NaN                  NaN
# 1992-01-01   NaN         NaN    NaN      NaN     NaN                  60k
# 1993-01-01   NaN         NaN    NaN      NaN     NaN                77.8k
# 1994-01-01   NaN         NaN    NaN      NaN     NaN                  96k
# 1995-01-01   NaN         NaN    NaN      NaN     NaN                 115k
# 1996-01-01   NaN         NaN    NaN      NaN    5000                 160k
# 1997-01-01   NaN         NaN   8000      NaN     10k                 200k
# 1998-01-01   NaN         NaN    10k      NaN     15k                 250k
# 1999-01-01   NaN         NaN    12k      NaN     20k                 300k
# 2000-01-01   NaN         NaN    15k      NaN     25k                 400k
# 2001-01-01   NaN         NaN    17k      NaN     30k                 420k
# ...

# %%
df_computers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 17 entries, 1990-01-01 to 2006-01-01
# Columns: 196 entries, Aruba to Zimbabwe
# dtypes: object(196)
# memory usage: 26.2+ KB

# %%
df_computers.replace({"k": "000", "M": "000000"}, regex=True)
# Out:
# country     Aruba Afghanistan   Angola Anguilla Albania United Arab Emirates
# 1990-01-01    NaN         NaN      NaN      NaN     NaN                  NaN  \
# 1991-01-01    NaN         NaN      NaN      NaN     NaN                  NaN
# 1992-01-01    NaN         NaN      NaN      NaN     NaN                60000
# 1993-01-01    NaN         NaN      NaN      NaN     NaN              77.8000
# 1994-01-01    NaN         NaN      NaN      NaN     NaN                96000
# 1995-01-01    NaN         NaN      NaN      NaN     NaN               115000
# 1996-01-01    NaN         NaN      NaN      NaN    5000               160000
# 1997-01-01    NaN         NaN     8000      NaN   10000               200000
# 1998-01-01    NaN         NaN    10000      NaN   15000               250000
# 1999-01-01    NaN         NaN    12000      NaN   20000               300000
# 2000-01-01    NaN         NaN    15000      NaN   25000               400000
# ...

# %%
def eval_numbers(str_num):
    if isinstance(str_num, float):
        return str_num
    return eval(str_num)

# %%
df_computers = df_computers.replace({"k": "*1e3", "M": "*1e6"}, regex=True).applymap(eval_numbers)
df_computers
# Out:
# country       Aruba  Afghanistan    Angola  Anguilla   Albania
# 1990-01-01      NaN          NaN       NaN       NaN       NaN  \
# 1991-01-01      NaN          NaN       NaN       NaN       NaN
# 1992-01-01      NaN          NaN       NaN       NaN       NaN
# 1993-01-01      NaN          NaN       NaN       NaN       NaN
# 1994-01-01      NaN          NaN       NaN       NaN       NaN
# 1995-01-01      NaN          NaN       NaN       NaN       NaN
# 1996-01-01      NaN          NaN       NaN       NaN    5000.0
# 1997-01-01      NaN          NaN    8000.0       NaN   10000.0
# 1998-01-01      NaN          NaN   10000.0       NaN   15000.0
# 1999-01-01      NaN          NaN   12000.0       NaN   20000.0
# 2000-01-01      NaN          NaN   15000.0       NaN   25000.0
# 2001-01-01      NaN          NaN   17000.0       NaN   30000.0
# 2002-01-01      NaN          NaN   27000.0       NaN   36000.0
# 2003-01-01      NaN          NaN       NaN    1500.0   42000.0
# ...

# %%
df_no_nan = df_computers.iloc[-5:].dropna(axis=1).astype(int)
df_no_nan
# Out:
# country     Albania  United Arab Emirates  Antigua and Barbuda  Azerbaijan
# 2002-01-01    36000                450000                 9000       84300  \
# 2003-01-01    42000                650000                10000      123000
# 2004-01-01    48000                850000                11000      149000
# 2005-01-01    54000               1050000                12100      195000
# 2006-01-01   120000               1400000                17500      177000
#
# country     Burundi  Belgium  Benin  Burkina Faso  Bangladesh  Bahrain  ...
# 2002-01-01     4200  2800000  15000         50000      450000   107000  ...  \
# 2003-01-01    13000  3300000  25800         60000     1050000   114000  ...
# 2004-01-01    34000  3630000  30000         70000     1650000   121000  ...
# 2005-01-01    55000  3950000  32000         80000     2250000   128000  ...
# 2006-01-01    65000  4400000  50000         90000     3500000   135000  ...
#
# ...

# %%
(df_no_nan.iloc[-1] - df_no_nan.iloc[0]) / df_no_nan.iloc[0]
# Out:
# country
# Albania                  2.333333
# United Arab Emirates     2.111111
# Antigua and Barbuda      0.944444
# Azerbaijan               1.099644
# Burundi                 14.476190
#                           ...
# Ukraine                  1.229232
# Vietnam                  9.149999
# Samoa                    2.500000
# Yemen                    3.137931
# Zimbabwe                 0.441667
# Length: 93, dtype: float64

# %% [markdown]
# ## Facts countries

# %%
df_facts = pd.read_csv("../Data/Trziste racunala i pametnih telefona/facts_countries.csv", sep=";", skiprows=[1])
df_facts
# Out:
#             Country  Area(sq km)  Birth rate(births/1000 population)
# 0       Afghanistan       647500                               47.02  \
# 1          Akrotiri          123                                 NaN
# 2           Albania        28748                               15.08
# 3           Algeria      2381740                               17.13
# 4    American Samoa          199                               23.13
# ..              ...          ...                                 ...
# 258       West Bank         5860                               32.37
# 259  Western Sahara       266000                                 NaN
# 260           Yemen       527970                               43.07
# 261          Zambia       752614                               41.38
# 262        Zimbabwe       390580                               29.74
#
#      Current account balance  Death rate(deaths/1000 population)
# 0                        NaN                               20.75  \
# ...

# %%
df_facts_no_nan = df_facts[["Country", "Public debt(% of GDP)"]].dropna()
df_facts_no_nan
# Out:
#         Country  Public debt(% of GDP)
# 3       Algeria                   37.4
# 10    Argentina                  118.0
# 14    Australia                   17.4
# 15      Austria                   64.2
# 16   Azerbaijan                   18.9
# ..          ...                    ...
# 253   Venezuela                   43.1
# 254     Vietnam                   65.9
# 260       Yemen                   46.4
# 261      Zambia                  127.5
# 262    Zimbabwe                   52.3
#
# [108 rows x 2 columns]

# %%
df_facts_no_nan.pivot_table(columns="Country", values="Public debt(% of GDP)")
# Out:
# Country                Algeria  Argentina  Australia  Austria  Azerbaijan
# Public debt(% of GDP)     37.4      118.0       17.4     64.2        18.9  \
#
# Country                Bahrain  Bangladesh  Belgium  Botswana  Brazil  ...
# Public debt(% of GDP)     63.8        43.0     96.2       8.6    52.0  ...  \
#
# Country                Ukraine  United Arab Emirates  United Kingdom
# Public debt(% of GDP)     24.7                  17.6            39.6  \
#
# Country                United States  Uzbekistan  Venezuela  Vietnam  Yemen
# Public debt(% of GDP)           65.0        41.5       43.1     65.9   46.4  \
#
# Country                Zambia  Zimbabwe
# Public debt(% of GDP)   127.5      52.3
#
# [1 rows x 108 columns]
