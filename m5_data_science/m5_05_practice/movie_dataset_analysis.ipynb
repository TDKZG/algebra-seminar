# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_movies = pd.read_csv("../Data/Filmovi/movie_dataset.csv", index_col=0)
df_movies
# Out:
#           budget                                    genres
# index
# 0      237000000  Action Adventure Fantasy Science Fiction  \
# 1      300000000                  Adventure Fantasy Action
# 2      245000000                    Action Adventure Crime
# 3      250000000               Action Crime Drama Thriller
# 4      260000000          Action Adventure Science Fiction
# ...          ...                                       ...
# 4798      220000                     Action Crime Thriller
# 4799        9000                            Comedy Romance
# 4800           0             Comedy Drama Romance TV Movie
# 4801           0                                       NaN
# 4802           0                               Documentary
#
#                                                 homepage      id
# index
# 0                            http://www.avatarmovie.com/   19995  \
# 1           http://disney.go.com/disneypictures/pirates/     285
# ...

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4803 entries, 0 to 4802
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4775 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4391 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %%
df_movies.budget.describe()
# Out:
# count    4.803000e+03
# mean     2.904504e+07
# std      4.072239e+07
# min      0.000000e+00
# 25%      7.900000e+05
# 50%      1.500000e+07
# 75%      4.000000e+07
# max      3.800000e+08
# Name: budget, dtype: float64

# %%
df_movies.popularity.describe()
# Out:
# count    4803.000000
# mean       21.492301
# std        31.816650
# min         0.000000
# 25%         4.668070
# 50%        12.921594
# 75%        28.313505
# max       875.581305
# Name: popularity, dtype: float64

# %%
df_budget_popularity = df_movies[["budget", "popularity"]]
df_budget_popularity.head()
# Out:
#           budget  popularity
# index
# 0      237000000  150.437577
# 1      300000000  139.082615
# 2      245000000  107.376788
# 3      250000000  112.312950
# 4      260000000   43.926995

# %%
df_budget_popularity.describe()
# Out:
#              budget   popularity
# count  4.803000e+03  4803.000000
# mean   2.904504e+07    21.492301
# std    4.072239e+07    31.816650
# min    0.000000e+00     0.000000
# 25%    7.900000e+05     4.668070
# 50%    1.500000e+07    12.921594
# 75%    4.000000e+07    28.313505
# max    3.800000e+08   875.581305

# %%
df_budget_popularity.plot(subplots=True)
# Out:
# array([<Axes: xlabel='index'>, <Axes: xlabel='index'>], dtype=object)

# %%
df_budget_popularity.iloc[::10].plot(style="o", markersize=1, subplots=True)
# Out:
# array([<Axes: xlabel='index'>, <Axes: xlabel='index'>], dtype=object)

# %%
df_budget_popularity.budget.plot(kind="hist", bins=100)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df_budget_popularity.popularity.plot(kind="hist", bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df_budget_popularity.plot(kind="box", subplots=True)
# Out:
# budget           Axes(0.125,0.11;0.352273x0.77)
# popularity    Axes(0.547727,0.11;0.352273x0.77)
# dtype: object

# %%
df_budget_popularity.plot(
    kind="scatter",
    x="budget",
    y="popularity",
    alpha=0.5
)
# Out:
# <Axes: xlabel='budget', ylabel='popularity'>

# %%
df_no_outliers = df_budget_popularity[(df_budget_popularity.popularity < 50) & (df_budget_popularity.budget < 8e7)]
df_no_outliers.plot(kind="box", subplots=True)
# Out:
# budget           Axes(0.125,0.11;0.352273x0.77)
# popularity    Axes(0.547727,0.11;0.352273x0.77)
# dtype: object

# %%
df_no_outliers.iloc[::5].plot(
    kind="scatter",
    x="budget",
    y="popularity",
    alpha=1
)
# Out:
# <Axes: xlabel='budget', ylabel='popularity'>

# %%
df_budget_popularity.corr()
# Out:
#               budget  popularity
# budget      1.000000    0.505414
# popularity  0.505414    1.000000

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4803 entries, 0 to 4802
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4775 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4391 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %%
df_movies.corr(numeric_only=True)
# Out:
#                 budget        id  popularity   revenue   runtime
# budget        1.000000 -0.089377    0.505414  0.730823  0.269851  \
# id           -0.089377  1.000000    0.031202 -0.050425 -0.153536
# popularity    0.505414  0.031202    1.000000  0.644724  0.225502
# revenue       0.730823 -0.050425    0.644724  1.000000  0.251093
# runtime       0.269851 -0.153536    0.225502  0.251093  1.000000
# vote_average  0.093146 -0.270595    0.273952  0.197150  0.375046
# vote_count    0.593180 -0.004128    0.778130  0.781487  0.271944
#
#               vote_average  vote_count
# budget            0.093146    0.593180
# id               -0.270595   -0.004128
# popularity        0.273952    0.778130
# revenue           0.197150    0.781487
# runtime           0.375046    0.271944
# vote_average      1.000000    0.312997
# vote_count        0.312997    1.000000

# %%
import seaborn as sns

# %%
cor = df_movies.corr(numeric_only=True)
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
# Out:
# <Axes: >

# %%
df_movies.plot(
    kind="scatter",
    x="vote_count",
    y="popularity",
    alpha=0.5
)
# Out:
# <Axes: xlabel='vote_count', ylabel='popularity'>

# %%
df_movies[(df_movies.popularity < 200) & (df_movies.vote_count < 8000)].plot(
    kind="scatter",
    x="vote_count",
    y="popularity",
    alpha=0.5
)
# Out:
# <Axes: xlabel='vote_count', ylabel='popularity'>

# %%
df_movies[(df_movies.popularity < 100) & (df_movies.vote_count < 1e9)].plot(
    kind="scatter",
    x="revenue",
    y="popularity",
    alpha=0.5
)
# Out:
# <Axes: xlabel='revenue', ylabel='popularity'>
